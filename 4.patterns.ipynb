# %%
for i in range(9):
    for j in range(9):
        if(i==j or i+j==8):
            print("*",end="")
        else:
            print(" ",end="")
    print()
# Out:
# *       *
#  *     *
#   *   *
#    * *
#     *
#    * *
#   *   *
#  *     *
# *       *

# %%
for i in range(6):
    for j in range(i):
        print("*",end="")
    print()

i=1
while i<=5:
    j=1
    while j<=i:
        print("*",end="")
        j+=1
    print()
    i+=1
# Out:
# *
# **
# ***
# ****
# *****
# *
# **
# ***
# ****
# *****

# %%
for i in range(5,0,-1):
    for j in range(i):
        print("*",end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
for i in range(5):
    for j in range(5):
        print("*",end="")
    print()
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
for i in range(1,6):
    for j in range(i,0,-1):
        print(j,end="")
    print()
# Out:
# 1
# 21
# 321
# 4321
# 54321

# %%
for i in range(1,6):
    for j in range(1,i+1):
        print(j,end="")
    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
for i in range(1,6):
    for j in range(i,0,-1):
        print(j,end="")
    print()
# Out:
# 1
# 21
# 321
# 4321
# 54321

# %%
for i in range (5,0,-1):
    for j in range(1,i+1):
        print(j,end="")
    print()
# Out:
# 12345
# 1234
# 123
# 12
# 1

# %%
for i in range(5,0,-1):
    for j in range(,6):
        print(j,end="")
    print()
# Out:
# 45
# 345
# 2345
# 12345
# 012345

# %%
for i in range(4):
    for j in range(1,5):
        print(j,end="")
    print()
# Out:
# 1234
# 1234
# 1234
# 1234
